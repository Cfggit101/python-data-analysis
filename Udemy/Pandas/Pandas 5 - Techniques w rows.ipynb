# %%
#TECHNIQUES WITH ROWS

# %%
import numpy as no
import pandas as pd

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.index
#default range index but maybe we want to set index to a value thats actually a column - always must be a unique value for each row!
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df["Payment ID"].nunique()
#for how many unique values you have in a particular column
# Out:
# 243

# %%
df["Payment ID"].unique()
# Out:
# array(['Sun2959', 'Sun4608', 'Sun4458', 'Sun5260', 'Sun2251', 'Sun9679',
#        'Sun5985', 'Sun8157', 'Sun6820', 'Sun3775', 'Sun2546', 'Sun6686',
#        'Sun1300', 'Sun2971', 'Sun3848', 'Sun1878', 'Sun9715', 'Sun2998',
#        'Sun2789', 'Sat9213', 'Sat1709', 'Sat9618', 'Sat9786', 'Sat239',
#        'Sat6236', 'Sat907', 'Sat6651', 'Sat394', 'Sat3697', 'Sat2467',
#        'Sat4099', 'Sat4947', 'Sat1327', 'Sat6649', 'Sat8124', 'Sat632',
#        'Sat9139', 'Sat6406', 'Sat4056', 'Sat6373', 'Sat8549', 'Sun9460',
#        'Sun1699', 'Sun3279', 'Sun2274', 'Sun8643', 'Sun7097', 'Sun9677',
#        'Sun4142', 'Sun9774', 'Sun2021', 'Sun4474', 'Sun6165', 'Sun4561',
#        'Sun9470', 'Sun1118', 'Sat8903', 'Sat8980', 'Sat6683', 'Sat8139',
#        'Sat2353', 'Sat3030', 'Sat2265', 'Sat4178', 'Sat1667', 'Sat6840',
#        'Sat4750', 'Sat3455', 'Sat561', 'Sat855', 'Sat2100', 'Sat3469',
#        'Sat1967', 'Sat6065', 'Sat6548', 'Sat5056', 'Sat9908', 'Thur4924',
# ...

# %%
df.set_index("Payment ID")
#this change wont be permanent unless i put 'df = ' - that way resetting the value of the df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df = df.set_index("Payment ID")
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df = df.reset_index()
#to go back to the range index
#will grab the index and set it as a column

# %%
df
# Out:
#     Payment ID  index  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959      0       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608      1       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458      2       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260      3       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251      4       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...    ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657    239       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766    240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880    241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17    242       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672    243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# ...

# %%
df = df.set_index("Payment ID")

# %%
df
# Out:
#             index  total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959         0       16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608         1       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251         4       24.59  3.61  Female     No   Sun  Dinner     4
# ...           ...         ...   ...     ...    ...   ...     ...   ...
# Sat2657       239       29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766       240       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       241       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         242       17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       243       18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# ...

# %%
#TO GRAB ROWS IN TERMS OF RANGEINDEX --> dependent of you knowing the location of the data
df.iloc[0]
# Out:
# index                                0
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
#TO GRAB ROWS IN TERMS OF NAMEINDEX --> dependent of you knowing the label-name of the data
df.loc["Sun2959"]
# Out:
# index                                0
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
#IF I WANNA GRAB MULTIPLE ROWS, I CAN USE PYTHON'S SLICE NOTATION FOR THESE

# %%
df.iloc[0:4]
#will grab from 0 up to but NOT INCLUDING 4
#this is why people use .iloc bc it then allows you to take slices of that data (do this slice notation)
# Out:
#             index  total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608         1       10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458         2       21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260         3       23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251         4       24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# Sun4458                 7.00    Travis Walters  6011812112971322
# Sun5260                11.84  Nathaniel Harris  4676137647685994
# Sun2251                 6.15      Tonya Carter  4832732618637221

# %%
#multiple rows with name-label:
#gatta pass a list of those string labels i want
df.loc[["Sun4608", "Sun5260"]]
# Out:
#             index  total_bill   tip   sex smoker  day    time  size  \
# Payment ID
# Sun4608         1       10.34  1.66  Male     No  Sun  Dinner     3
# Sun5260         3       23.68  3.31  Male     No  Sun  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# Sun5260                11.84  Nathaniel Harris  4676137647685994

# %%
#REMOVING ROWS
df = df.drop("Sun2251", axis=0)
#axis = 0 indicates the rows, but by default it is already set to 0 - just gotta put it when i want to remove columns ('axis=1')
#again if i wanna make it permanent --> 'df = ' (reassignment)
#cant do it by name range index
df
# Out:
#             index  total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4458         2       21.01  3.50    Male     No   Sun  Dinner     3
# Sun9679         5       25.29  4.71    Male     No   Sun  Dinner     4
# Sun5985         6        8.77  2.00    Male     No   Sun  Dinner     2
# Sun8157         7       26.88  3.12    Male     No   Sun  Dinner     4
# Sun6820         8       15.04  1.96    Male     No   Sun  Dinner     2
# ...           ...         ...   ...     ...    ...   ...     ...   ...
# Sat2657       239       29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766       240       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       241       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         242       17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       243       18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# ...

# %%
#to drop in terms of rangeindex i can't remove one specifically but i can slice it and just select the ones i want
#--> not always think of removing but about selecting the ones im interested in

# %%
#TO ADD NEW ROW 
#the new row gotta match with the dimensions of the existing rows
one_row = df.iloc[0]
one_row
#gotta be the same structure as this - some data could be missing (by putting 'no' f ex) but it has to match the structure and length
# Out:
# index                              2
# total_bill                     21.01
# tip                              3.5
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                 7.0
# Payer Name            Travis Walters
# CC Number           6011812112971322
# Name: Sun4458, dtype: object

# %%
df = df.append(one_row)
df
#dont know why it doesnt recognice append but this should add this row to the end, that way i'd have it on []
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17828\1396444434.py in ?()
# ----> 1 df = df.append(one_row)
#       2 df
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
