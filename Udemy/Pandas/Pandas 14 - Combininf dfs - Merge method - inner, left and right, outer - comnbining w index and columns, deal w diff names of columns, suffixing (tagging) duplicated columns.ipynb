# %%
import numpy as np
import pandas as pd

# %%
#COMBINING DFS
#INNER MERGE METHOD
#when they are not in the same order or format 
#simmilar to 'join' command in SQL

# its pd.merge() - takes in a key argument 'how' - three ways of merging w how:
# 1) Inner
# 2) Outter
# 3) Left or Right

#The main idea is to decide how to deal w the info only present in one of the joined tables - you wanna keep the ones not commons (w NaNs) or you wanna drop them altogether

#Merging process:
# 1º - decide on what columnt to merge together
    #the primary column should be a primary identifier - meaning unique per row
    # the on column should be present in both tables being merged - and represents the same thing in both tables
# 2º - decide how to merge the tables on the elected column
    #w 'how' = 'inner' --> the result will be the set of records that match in both tables - ill only be looking at the ones that are present in both tables - like a venn diagram (only the area common to both circles)
    # would look like --> pd.merge(df1, df2, how = 'inner', on = 'on column') -- will return the common values of the 'on column' w the values from both dfs associated to them

# %%
registrations = pd.DataFrame({'reg_id':[1,2,3,4],'name':['Andrew','Bobo','Claire','David']})
logins = pd.DataFrame({'log_id':[1,2,3,4],'name':['Xavier','Andrew','Yolanda','Bobo']})

# %%
registrations
# Out:
#    reg_id    name
# 0       1  Andrew
# 1       2    Bobo
# 2       3  Claire
# 3       4   David

# %%
logins
#could reset the column to be the index if wanted
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'MergeHow' = 'inner', on: 'IndexLabel | AnyArrayLike | None' = None, left_on: 'IndexLabel | AnyArrayLike | None' = None, right_on: 'IndexLabel | AnyArrayLike | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool | None' = None, indicator: 'str | bool' = False, validate: 'str | None' = None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     A named Series object is treated as a DataFrame with a single named column.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
# ...

# %%
pd.merge(registrations, logins, how = 'inner', on ='name')
#as you are taking values present in both tables, the order doesnt really matter (just in inner)
# Out:
#    reg_id    name  log_id
# 0       1  Andrew       2
# 1       2    Bobo       4

# %%
#LEFT AND RIGHT MERGE
#order in which i pass in the df here DOES matter!!! - first i pass in is the left one and second the right one
#if i put 'how = 'left'' - itll return all values in the left one and only the common ones of the right one -- ill have NaN in the values present in left but not in right one
#in the 'right' situation will happen the opposite - will have all form right and only the common ones of left

# %%
pd.merge(left = registrations, right = logins, how = 'left', on = 'name')
# Out:
#    reg_id    name  log_id
# 0       1  Andrew     2.0
# 1       2    Bobo     4.0
# 2       3  Claire     NaN
# 3       4   David     NaN

# %%
df = pd.merge(left = registrations, right = logins, how = 'right', on = 'name')
df
#pandas is actually smart enough to know in this case which should be the 'on column', so i could delete that part, but better to clarify it so i can know my intentions when i wrote it
# Out:
#    reg_id     name  log_id
# 0     NaN   Xavier       1
# 1     1.0   Andrew       2
# 2     NaN  Yolanda       3
# 3     2.0     Bobo       4

# %%
df.index = df['name']
df
# Out:
#          reg_id     name  log_id
# name
# Xavier      NaN   Xavier       1
# Andrew      1.0   Andrew       2
# Yolanda     NaN  Yolanda       3
# Bobo        2.0     Bobo       4

# %%
#OUTTER MERGE:
#allows us to include everything present in both tables
pd.merge(registrations, logins, how='outer', on='name')
#the order of the dfs not important either
# Out:
#    reg_id     name  log_id
# 0     1.0   Andrew     2.0
# 1     2.0     Bobo     4.0
# 2     3.0   Claire     NaN
# 3     4.0    David     NaN
# 4     NaN   Xavier     1.0
# 5     NaN  Yolanda     3.0

# %%
#JOIN ON INDEX INSTEAD OF COLUMNS
registrations
#now i wanna merge on the index of registrations and the column 'name' in logins
#the merge function takes also a:
    #'left_index' (index of left table)  -- boolean
    #'right_index' (index of right table)   -- boolean; 
#parameters as well as a 
    #'left_on' (a column in the left table) -- enter name of the specific column
    #'right_on' (a column in the right table) -- enter name of the specific column
#we can combine this and use it:
# Out:
#         reg_id
# name
# Andrew       1
# Bobo         2
# Claire       3
# David        4

# %%
pd.merge(registrations, logins, how = 'inner', left_index = True , right_on = 'name' )
#in the column one i have to enter the name of the column
# Out:
#    reg_id  log_id    name
# 1       1       2  Andrew
# 3       2       4    Bobo

# %%
#HOW TO DEAL W DIFFERENT NAMES OF THE 'ON COLUMN'
#when i wwanna merge two columns that mean the same but are called different
registrations = registrations = pd.DataFrame({'reg_id':[1,2,3,4],'name':['Andrew','Bobo','Claire','David']})
registrations
# Out:
#    reg_id    name
# 0       1  Andrew
# 1       2    Bobo
# 2       3  Claire
# 3       4   David

# %%
registrations.columns = ['reg_id', 'reg_name']
registrations
# Out:
#    reg_id reg_name
# 0       1   Andrew
# 1       2     Bobo
# 2       3   Claire
# 3       4    David

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
#i just specify which columns i wanna "see" from both tables using again the 'left_on'/'right_on'
pd.merge(registrations, logins, how= 'inner', left_on= 'reg_name', right_on= 'name')
#its gonna retunr 4 columns cos eventhough they mean the same thing, its gonna keem 'reg_name' separate form 'name', but we can just drop one of them and thats it - w 'results.drop('reg_name', axis=1)' - remember to put 'axis=1' so it drops the column
# Out:
#    reg_id reg_name  id    name
# 0       1   Andrew   2  Andrew
# 1       2     Bobo   4    Bobo

# %%
# HOW TO ADD OR TAG DUPLICATE COLUMNS

# %%
registrations.columns = ['id','name']
registrations
# Out:
#    id    name
# 0   1  Andrew
# 1   2    Bobo
# 2   3  Claire
# 3   4   David

# %%
logins.columns = ['id','name']
logins
# Out:
#    id     name
# 0   1   Xavier
# 1   2   Andrew
# 2   3  Yolanda
# 3   4     Bobo

# %%
registrations['name'].dtype
# Out:
# dtype('O')

# %%
#you got this situation where you got two columns that are called the same but represent different things - cos as they are in specific dfs they are refering to those dfs (id reg and id log), but are common in both when we look at both og them 
pd.merge(registrations, logins, how = 'inner', on ='name')
#by default, pandas will label them to differenciate them ('x' for left table and 'y' for right table)
# Out:
#    id_x    name  id_y
# 0     1  Andrew     2
# 1     2    Bobo     4

# %%
#but i can provide the suffixes i want there to be used - as a touple of strings:
pd.merge(registrations, logins, how = 'inner', on ='name', suffixes=('_reg','_log'))
#first one i enter for the one that comes from the left one, and second one for the one that comes from the right one

#And so now, what's gonna happen is, if you have columns that happen to have the exact same name in both tables
and you're not joining on those columns, so you expect both

ID columns to be returned in order to specify which ID goes

with which table, instead of using the default suffix

that Pandas assigns, we can provide our own tuple here.
# Out:
#    id_reg    name  id_log
# 0       1  Andrew       2
# 1       2    Bobo       4
