# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#TECHNIQUES WITH COLUMNS

# %%
df["total_bill"]
#its a series! (format) cos im only calling one of them (when i call two, then i'll have a dataframe (see next))
#tab for autocomplete
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
mycols = ['total_bill','tip']
df[mycols]
#grabbing a subset of that dataframe --> its no longer a series but a datafrmae cos there are two series there (that share indexs)
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
#this would be the same but be aware of DOUBLE BRAKETS! cos im calling a list!!!!
#--> to pass a list of columns names, i use double brakets
df[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
#TO ADD NEW COLUMNS BASED ON EXISTING ONES:
df['tip'] / df['total_bill'] *100
#simply reference then and put the operator 
#(tip included in total bill)
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Length: 244, dtype: float64

# %%
#and now i create a new columns with that:
df['tip_percentage'] = df['tip'] / df['total_bill'] *100
#reference it as if it already existed
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID',
#        'tip_percentage'],
#       dtype='object')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
#if i reference an existing columns, itll overwrite the existing one --> be careful when asigning names when creating new ones!!!

# %%
#TO ROUND NUMBERS:
df['tip_percentage'] = np.round(df['tip_percentage'],3)
df
#i overwrite it where i want
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
#or:
df['tip_percentage'] = np.round(df['tip'] / df['total_bill'] *100, 3)
df
#as round lets me introduce a vlaue and a nº of digits i want, i can create it at the same time i round it
#or overwrite it as before
# Out:
#      total_bill   tip     sex smoker   day    time  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner              6.15
# ..          ...   ...     ...    ...   ...     ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# 0    Christy Cunningham  3560325168603410    Sun2959           5.945
# ...

# %%
#TO REMOVE COLUMNS:
df = df.drop('size',axis=1)
df
#got to indicate the columns or columns you wanna remove and also 'axis=0' would indicate its a row what you wanna remove, and 'axis=1' would indicate a column
#be careful - if i equal it to df, itll remove it from the dataframe
#if i only use drop but not replace the original df with that new modified df, it wont affect the original!
#calls error cos it doesnt exist anymore (cos i removed it before), so now it doesnt find it
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[99], line 2
#       1 #TO REMOVE COLUMNS:
# ----> 2 df = df.drop('size',axis=1)
#       3 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
#to remove permanently form my dataframe i can:
#1) in the drop() function put 'inplace=True' - and that will replace the original with this new one with the removed column
#2) but better the df = ...

# %%
#axis = 0 is row and axis = 1 is columns bc of the default shape of Numpy arrays
df.shape
#so a
# Out:
# (244, 11)
